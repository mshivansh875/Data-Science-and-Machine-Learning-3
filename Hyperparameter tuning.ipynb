# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
# breast_cancer_dataset

# %%
data_frame = pd.DataFrame(breast_cancer_dataset.data,columns=breast_cancer_dataset.feature_names)

# %%
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
data_frame['label'] = breast_cancer_dataset.target

# %%
data_frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  label
# 0          0.4601                  0.11890      0
# 1          0.2750                  0.08902      0
# 2          0.3613                  0.08758      0
# 3          0.6638                  0.17300      0
# 4          0.2364                  0.07678      0
#
# [5 rows x 31 columns]

# %%
data_frame.shape
# Out:
# (569, 31)

# %%
data_frame.isnull().sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# label                      0
# dtype: int64

# %%
data_frame['label'].value_counts()
# Out:
# label
# 1    357
# 0    212
# Name: count, dtype: int64

# %% [markdown]
# 1-> Benign
# 0-> Malignent

# %%
X = data_frame.drop(columns = 'label',axis=1)
y = data_frame['label']

# %%
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: label, dtype: int32

# %%
X = np.asarray(X)
y = np.asarray(y)

# %% [markdown]
# ### GridSearchCV

# %% [markdown]
# Gridsearch cv is determining the best parameter for our model

# %%
model = SVC()

# %%
parameters = {
    'kernel':['linear','poly','rbf','sigmoid'],
    'C':[1,5,10,20]
}

# %%
classifier = GridSearchCV(model,parameters,cv=5)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([2.74820557e+00, 6.07371330e-03, 9.06305313e-03, 2.16137886e-02,
#         5.52232461e+00, 7.64436722e-03, 8.89668465e-03, 1.87024117e-02,
#         7.89253082e+00, 8.79302025e-03, 6.82396889e-03, 2.32314587e-02,
#         1.33074691e+01, 9.57913399e-03, 1.36773109e-02, 2.56031513e-02]),
#  'std_fit_time': array([1.07383832e+00, 1.78034810e-03, 4.13624113e-03, 4.05077982e-03,
#         1.10182047e+00, 2.49247161e-03, 1.51906994e-03, 3.03740292e-03,
#         1.69317065e+00, 1.50950098e-03, 2.49935647e-03, 1.86196857e-03,
#         4.19321746e+00, 1.04133308e-03, 5.25916846e-03, 6.06400473e-03]),
#  'mean_score_time': array([1.21426582e-03, 2.68831253e-03, 4.05063629e-03, 5.41119576e-03,
#         2.84671783e-05, 8.04424286e-04, 4.20398712e-03, 5.41234016e-03,
#         3.06959152e-03, 7.57455826e-04, 4.76870537e-03, 3.54838371e-03,
#         1.01318359e-03, 2.01430321e-03, 7.43570328e-03, 9.49769020e-03]),
#  'std_score_time': array([2.42853165e-03, 2.22803982e-03, 2.95485572e-03, 3.07244255e-03,
#         5.69343567e-05, 1.18770494e-03, 8.10610356e-04, 2.79075105e-03,
#         2.58978895e-03, 9.30779415e-04, 2.75120347e-03, 2.53327399e-03,
#         2.02636719e-03, 4.02860641e-03, 5.60654464e-03, 3.20668157e-03]),
#  'param_C': masked_array(data=[1, 1, 1, 1, 5, 5, 5, 5, 10, 10, 10, 10, 20, 20, 20, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'poly', 'rbf', 'sigmoid', 'linear', 'poly',
#                     'rbf', 'sigmoid', 'linear', 'poly', 'rbf', 'sigmoid',
#                     'linear', 'poly', 'rbf', 'sigmoid'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'poly'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'sigmoid'},
#   {'C': 5, 'kernel': 'linear'},
#   {'C': 5, 'kernel': 'poly'},
#   {'C': 5, 'kernel': 'rbf'},
#   {'C': 5, 'kernel': 'sigmoid'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'poly'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'sigmoid'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'poly'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'sigmoid'}],
#  'split0_test_score': array([0.94736842, 0.84210526, 0.85087719, 0.54385965, 0.94736842,
#         0.88596491, 0.88596491, 0.49122807, 0.93859649, 0.88596491,
#         0.87719298, 0.48245614, 0.92982456, 0.87719298, 0.87719298,
#         0.47368421]),
#  'split1_test_score': array([0.92982456, 0.88596491, 0.89473684, 0.45614035, 0.93859649,
#         0.9122807 , 0.92982456, 0.42105263, 0.93859649, 0.92105263,
#         0.92105263, 0.40350877, 0.95614035, 0.92105263, 0.92105263,
#         0.40350877]),
#  'split2_test_score': array([0.97368421, 0.92982456, 0.92982456, 0.46491228, 0.97368421,
#         0.92105263, 0.93859649, 0.42105263, 0.97368421, 0.90350877,
#         0.9122807 , 0.42105263, 0.95614035, 0.90350877, 0.92105263,
#         0.42105263]),
#  'split3_test_score': array([0.92105263, 0.94736842, 0.94736842, 0.38596491, 0.92982456,
#         0.93859649, 0.94736842, 0.35087719, 0.94736842, 0.93859649,
#         0.95614035, 0.34210526, 0.93859649, 0.93859649, 0.94736842,
#         0.34210526]),
#  'split4_test_score': array([0.95575221, 0.9380531 , 0.9380531 , 0.45132743, 0.96460177,
#         0.95575221, 0.95575221, 0.37168142, 0.96460177, 0.95575221,
#         0.94690265, 0.36283186, 0.96460177, 0.95575221, 0.9380531 ,
#         0.3539823 ]),
#  'mean_test_score': array([0.94553641, 0.90866325, 0.91217202, 0.46044093, 0.95081509,
#         0.92272939, 0.93150132, 0.41117839, 0.95256948, 0.920975  ,
#         0.92271386, 0.40239093, 0.9490607 , 0.91922062, 0.92094395,
#         0.39886664]),
#  'std_test_score': array([0.01868869, 0.03938232, 0.03544367, 0.05025317, 0.01621632,
#         0.02368918, 0.02435811, 0.04857818, 0.01419963, 0.02470123,
#         0.02787898, 0.0489065 , 0.01281637, 0.02730027, 0.02410455,
#         0.0476401 ]),
#  'rank_test_score': array([ 4, 12, 11, 13,  2,  6,  5, 14,  1,  8,  7, 15,  3, 10,  9, 16])}

# %%
# best parameter 

best_parameters = classifier.best_params_
best_parameters
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# highest accuracy

highest_accuracy = classifier.best_score_
highest_accuracy
# Out:
# 0.9525694767893185

# %%
# loading the results to the pandas dataframe
result = pd.DataFrame(classifier.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       2.748206      1.073838         0.001214        0.002429        1
# 1       0.006074      0.001780         0.002688        0.002228        1
# 2       0.009063      0.004136         0.004051        0.002955        1
# 3       0.021614      0.004051         0.005411        0.003072        1
# 4       5.522325      1.101820         0.000028        0.000057        5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.929825           0.973684           0.921053           0.955752
# 1           0.885965           0.929825           0.947368           0.938053
# 2           0.894737           0.929825           0.947368           0.938053
# 3           0.456140           0.464912           0.385965           0.451327
# 4           0.938596           0.973684           0.929825           0.964602
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.945536        0.018689                4
# 1         0.908663        0.039382               12
# 2         0.912172        0.035444               11
# 3         0.460441        0.050253               13
# 4         0.950815        0.016216                2

# %%
result.shape
# Out:
# (16, 15)

# %%
result.param_C.value_counts()
# Out:
# param_C
# 1     4
# 5     4
# 10    4
# 20    4
# Name: count, dtype: int64

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
grid_search_result
# Out:
#     param_C param_kernel  mean_test_score
# 0         1       linear         0.945536
# 1         1         poly         0.908663
# 2         1          rbf         0.912172
# 3         1      sigmoid         0.460441
# 4         5       linear         0.950815
# 5         5         poly         0.922729
# 6         5          rbf         0.931501
# 7         5      sigmoid         0.411178
# 8        10       linear         0.952569
# 9        10         poly         0.920975
# 10       10          rbf         0.922714
# 11       10      sigmoid         0.402391
# 12       20       linear         0.949061
# 13       20         poly         0.919221
# 14       20          rbf         0.920944
# 15       20      sigmoid         0.398867

# %% [markdown]
# # RandomizedSearchCV

# %%
model = SVC()

# %%
classifier = RandomizedSearchCV(model,parameters,cv=5)

# %%
classifier.fit(X,y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([7.59722443e+00, 6.10909462e-03, 1.72650814e-02, 1.74628735e-02,
#         6.06622696e-03, 1.28089721e+01, 8.27541351e-03, 9.34338570e-03,
#         1.71947002e-02, 6.44507408e-03]),
#  'std_fit_time': array([1.69859184e+00, 1.69770972e-03, 2.12052829e-03, 3.63576408e-03,
#         2.80928326e-03, 4.24050106e+00, 2.08971084e-03, 1.12962391e-03,
#         2.45279451e-03, 2.14010638e-03]),
#  'mean_score_time': array([0.00061908, 0.0034874 , 0.00435753, 0.00521479, 0.00493197,
#         0.00125589, 0.00368805, 0.00120511, 0.00688639, 0.00495391]),
#  'std_score_time': array([0.00123816, 0.00186555, 0.00278791, 0.00169958, 0.00314088,
#         0.00176576, 0.00207987, 0.00241022, 0.0032032 , 0.00147841]),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'sigmoid', 'sigmoid', 'rbf', 'linear',
#                     'rbf', 'poly', 'sigmoid', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'param_C': masked_array(data=[10, 5, 1, 20, 1, 20, 10, 20, 10, 20],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value=999999),
#  'params': [{'kernel': 'linear', 'C': 10},
#   {'kernel': 'rbf', 'C': 5},
#   {'kernel': 'sigmoid', 'C': 1},
#   {'kernel': 'sigmoid', 'C': 20},
#   {'kernel': 'rbf', 'C': 1},
#   {'kernel': 'linear', 'C': 20},
#   {'kernel': 'rbf', 'C': 10},
#   {'kernel': 'poly', 'C': 20},
#   {'kernel': 'sigmoid', 'C': 10},
#   {'kernel': 'rbf', 'C': 20}],
#  'split0_test_score': array([0.93859649, 0.88596491, 0.54385965, 0.47368421, 0.85087719,
#         0.92982456, 0.87719298, 0.87719298, 0.48245614, 0.87719298]),
#  'split1_test_score': array([0.93859649, 0.92982456, 0.45614035, 0.40350877, 0.89473684,
#         0.95614035, 0.92105263, 0.92105263, 0.40350877, 0.92105263]),
#  'split2_test_score': array([0.97368421, 0.93859649, 0.46491228, 0.42105263, 0.92982456,
#         0.95614035, 0.9122807 , 0.90350877, 0.42105263, 0.92105263]),
#  'split3_test_score': array([0.94736842, 0.94736842, 0.38596491, 0.34210526, 0.94736842,
#         0.93859649, 0.95614035, 0.93859649, 0.34210526, 0.94736842]),
#  'split4_test_score': array([0.96460177, 0.95575221, 0.45132743, 0.3539823 , 0.9380531 ,
#         0.96460177, 0.94690265, 0.95575221, 0.36283186, 0.9380531 ]),
#  'mean_test_score': array([0.95256948, 0.93150132, 0.46044093, 0.39886664, 0.91217202,
#         0.9490607 , 0.92271386, 0.91922062, 0.40239093, 0.92094395]),
#  'std_test_score': array([0.01419963, 0.02435811, 0.05025317, 0.0476401 , 0.03544367,
#         0.01281637, 0.02787898, 0.02730027, 0.0489065 , 0.02410455]),
#  'rank_test_score': array([ 1,  3,  8, 10,  7,  2,  4,  6,  9,  5])}

# %%
best_parameters = classifier.best_params_
best_parameters
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
highest_accuracy = classifier.best_score_
highest_accuracy
# Out:
# 0.9525694767893185

# %%
result = pd.DataFrame(classifier.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       7.597224      1.698592         0.000619        0.001238       linear
# 1       0.006109      0.001698         0.003487        0.001866          rbf
# 2       0.017265      0.002121         0.004358        0.002788      sigmoid
# 3       0.017463      0.003636         0.005215        0.001700      sigmoid
# 4       0.006066      0.002809         0.004932        0.003141          rbf
#
#    param_C                          params  split0_test_score  \
# 0       10   {'kernel': 'linear', 'C': 10}           0.938596
# 1        5       {'kernel': 'rbf', 'C': 5}           0.885965
# 2        1   {'kernel': 'sigmoid', 'C': 1}           0.543860
# 3       20  {'kernel': 'sigmoid', 'C': 20}           0.473684
# 4        1       {'kernel': 'rbf', 'C': 1}           0.850877
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.938596           0.973684           0.947368           0.964602
# 1           0.929825           0.938596           0.947368           0.955752
# 2           0.456140           0.464912           0.385965           0.451327
# 3           0.403509           0.421053           0.342105           0.353982
# 4           0.894737           0.929825           0.947368           0.938053
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.952569        0.014200                1
# 1         0.931501        0.024358                3
# 2         0.460441        0.050253                8
# 3         0.398867        0.047640               10
# 4         0.912172        0.035444                7

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0       10       linear         0.952569
# 1        5          rbf         0.931501
# 2        1      sigmoid         0.460441
# 3       20      sigmoid         0.398867
# 4        1          rbf         0.912172
# 5       20       linear         0.949061
# 6       10          rbf         0.922714
# 7       20         poly         0.919221
# 8       10      sigmoid         0.402391
# 9       20          rbf         0.920944
